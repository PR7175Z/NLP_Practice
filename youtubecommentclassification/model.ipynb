# %%
! pip install numpy
! pip install pandas
! pip install matplotlib
# Out:
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/46/69/8c4f928741c2a8efa255fdc7e9097527c6dc4e4df147e3cadc5d9357ce85/numpy-2.2.4-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.8 kB 445.2 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 648.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.6 MB 7.0 MB/s eta 0:00:02
#     --------------------------------------- 0.3/12.6 MB 3.9 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/12.6 MB 3.7 MB/s eta 0:00:04
#    - -------------------------------------- 0.5/12.6 MB 3.0 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/12.6 MB 2.9 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/12.6 MB 2.8 MB/s eta 0:00:05
# ...
