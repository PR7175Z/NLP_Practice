# %%
! pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-w87d963k
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-w87d963k
#   Resolved https://github.com/openai/whisper.git to commit c0d2f624c09dc18e709e37c2ad90c039a4eb72a2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting more-itertools (from openai-whisper==20250625)
#   Using cached more_itertools-10.7.0-py3-none-any.whl.metadata (37 kB)
# Collecting numba (from openai-whisper==20250625)
#   Using cached numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting numpy (from openai-whisper==20250625)
#   Using cached numpy-2.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting tiktoken (from openai-whisper==20250625)
#   Using cached tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: torch in ./env/lib/python3.11/site-packages (from openai-whisper==20250625) (2.7.1)
# Collecting tqdm (from openai-whisper==20250625)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: triton>=2 in ./env/lib/python3.11/site-packages (from openai-whisper==20250625) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in ./env/lib/python3.11/site-packages (from triton>=2->openai-whisper==20250625) (78.1.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba->openai-whisper==20250625)
#   Using cached llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Collecting numpy (from openai-whisper==20250625)
#   Using cached numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting regex>=2022.1.18 (from tiktoken->openai-whisper==20250625)
#   Using cached regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
# Collecting requests>=2.26.0 (from tiktoken->openai-whisper==20250625)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.26.0->tiktoken->openai-whisper==20250625)
#   Using cached charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests>=2.26.0->tiktoken->openai-whisper==20250625)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.26.0->tiktoken->openai-whisper==20250625)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.26.0->tiktoken->openai-whisper==20250625)
#   Using cached certifi-2025.7.14-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: filelock in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (1.14.0)
# Requirement already satisfied: networkx in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (3.5)
# Requirement already satisfied: jinja2 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (3.1.6)
# Requirement already satisfied: fsspec in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (2025.7.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in ./env/lib/python3.11/site-packages (from torch->openai-whisper==20250625) (1.11.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./env/lib/python3.11/site-packages (from sympy>=1.13.3->torch->openai-whisper==20250625) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./env/lib/python3.11/site-packages (from jinja2->torch->openai-whisper==20250625) (3.0.2)
# Using cached more_itertools-10.7.0-py3-none-any.whl (65 kB)
# Using cached numba-0.61.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
# Using cached llvmlite-0.44.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
# Using cached numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Using cached tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Using cached regex-2024.11.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (792 kB)
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (147 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached certifi-2025.7.14-py3-none-any.whl (162 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=9db994bec751a9731884819b07fa0247fc022144d60095c61ae3ccaea6d2093b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2eswle0n/wheels/1f/1d/98/9583695e6695a6ac0ad42d87511097dce5ba486647dbfecb0e
# Successfully built openai-whisper
# Installing collected packages: urllib3, tqdm, regex, numpy, more-itertools, llvmlite, idna, charset_normalizer, certifi, requests, numba, tiktoken, openai-whisper
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [openai-whisper]m [openai-whisper]
# Successfully installed certifi-2025.7.14 charset_normalizer-3.4.2 idna-3.10 llvmlite-0.44.0 more-itertools-10.7.0 numba-0.61.2 numpy-2.2.6 openai-whisper-20250625 regex-2024.11.6 requests-2.32.4 tiktoken-0.9.0 tqdm-4.67.1 urllib3-2.5.0

# %%
! pip install sounddevice numpy
# Out:
# Collecting sounddevice
#   Downloading sounddevice-0.5.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy in ./env/lib/python3.11/site-packages (2.2.6)
# Collecting CFFI>=1.0 (from sounddevice)
#   Using cached cffi-1.17.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from CFFI>=1.0->sounddevice)
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Downloading sounddevice-0.5.2-py3-none-any.whl (32 kB)
# Using cached cffi-1.17.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (467 kB)
# Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: pycparser, CFFI, sounddevice
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [sounddevice] [CFFI]
# Successfully installed CFFI-1.17.1 pycparser-2.22 sounddevice-0.5.2

# %%
! pip install pipwin
# Out:
# Collecting pipwin
#   Downloading pipwin-0.5.2.tar.gz (7.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docopt (from pipwin)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in ./env/lib/python3.11/site-packages (from pipwin) (2.32.4)
# Collecting pyprind (from pipwin)
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six in ./env/lib/python3.11/site-packages (from pipwin) (1.17.0)
# Collecting beautifulsoup4>=4.9.0 (from pipwin)
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting js2py (from pipwin)
#   Downloading Js2Py-0.74-py3-none-any.whl.metadata (868 bytes)
# Requirement already satisfied: packaging in ./env/lib/python3.11/site-packages (from pipwin) (25.0)
# Collecting pySmartDL>=1.3.1 (from pipwin)
#   Downloading pySmartDL-1.3.4-py3-none-any.whl.metadata (2.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.9.0->pipwin)
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./env/lib/python3.11/site-packages (from beautifulsoup4>=4.9.0->pipwin) (4.14.1)
# Collecting tzlocal>=1.2 (from js2py->pipwin)
#   Downloading tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting pyjsparser>=2.5.1 (from js2py->pipwin)
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in ./env/lib/python3.11/site-packages (from requests->pipwin) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.11/site-packages (from requests->pipwin) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./env/lib/python3.11/site-packages (from requests->pipwin) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.11/site-packages (from requests->pipwin) (2025.7.14)
# Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 6.1 MB/s eta 0:00:00-:--:--
# Downloading tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Building wheels for collected packages: pipwin, docopt, pyjsparser
#   DEPRECATION: Building 'pipwin' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pipwin'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for pipwin (setup.py) ... done
#   Created wheel for pipwin: filename=pipwin-0.5.2-py2.py3-none-any.whl size=8848 sha256=e33e5d4d3c3caf5c1340939e6e8c61ba4b4bc20d60a760ba5405e5c8bc6cd31b
#   Stored in directory: /home/aadimprajapati/.var/app/com.visualstudio.code/cache/pip/wheels/07/45/2e/51ee464b7c3407327439df34c2fc62f978a1e5084aaf23d201
#   DEPRECATION: Building 'docopt' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'docopt'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13782 sha256=a638ec9c75180adcaa560798eba5e3a6c7a2ae32daa872e5fa32203658ffeb21
#   Stored in directory: /home/aadimprajapati/.var/app/com.visualstudio.code/cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   DEPRECATION: Building 'pyjsparser' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pyjsparser'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for pyjsparser (setup.py) ... done
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=26011 sha256=3e82d7aefe364a5b69413e9fe72800fffa373f760d1ee9503c86437e55beb555
#   Stored in directory: /home/aadimprajapati/.var/app/com.visualstudio.code/cache/pip/wheels/a5/9a/30/1003e89ab4555b81840ca46d361bf184f1e6ad880cae3b62a9
# Successfully built pipwin docopt pyjsparser
# Installing collected packages: pySmartDL, pyprind, pyjsparser, docopt, tzlocal, soupsieve, js2py, beautifulsoup4, pipwin
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [pipwin]2m7/9 [beautifulsoup4]
# Successfully installed beautifulsoup4-4.13.4 docopt-0.6.2 js2py-0.74 pipwin-0.5.2 pySmartDL-1.3.4 pyjsparser-2.7.1 pyprind-2.11.3 soupsieve-2.7 tzlocal-5.3.1

# %%
! pip install scipy
# Out:
# Collecting scipy
#   Using cached scipy-1.16.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in ./env/lib/python3.11/site-packages (from scipy) (2.2.6)
# Using cached scipy-1.16.0-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.3 MB)
# Installing collected packages: scipy
# Successfully installed scipy-1.16.0

# %%
import whisper
import speech_recognition as sr
import numpy as np
import tempfile
import scipy.io.wavfile

# %%
model = whisper.load_model('base')
# Out:
# /run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/python3.11/site-packages/whisper/__init__.py:69: UserWarning: /home/aadimprajapati/.var/app/com.visualstudio.code/cache/whisper/base.pt exists, but the SHA256 checksum does not match; re-downloading the file
#   warnings.warn(
# 100%|███████████████████████████████████████| 139M/139M [00:32<00:00, 4.48MiB/s]

# %%
r = sr.Recognizer()

# %%
with sr.Microphone() as source:
    print("🎤 Speak something...")
    audio = r.listen(source, phrase_time_limit=5)
# Out:
# ALSA lib pcm_direct.c:1997:(snd1_pcm_direct_parse_open_conf) The field ipc_gid must be a valid group (create group audio)
# ALSA lib pcm_direct.c:1997:(snd1_pcm_direct_parse_open_conf) The field ipc_gid must be a valid group (create group audio)
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.hdmi.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM hdmi
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.hdmi.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM hdmi
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.modem.0:CARD=0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline:CARD=0,DEV=0
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.modem.0:CARD=0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline:CARD=0,DEV=0
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.modem.0:CARD=0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM phoneline
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.modem.0:CARD=0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM phoneline
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_oss.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_oss.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_oss.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_oss.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_pulse.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_pulse.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_pulse.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_pulse.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_upmix.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_upmix.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_upmix.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_upmix.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_vdownmix.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_vdownmix.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_vdownmix.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_vdownmix.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_usb_stream.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_usb_stream.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_usb_stream.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_usb_stream.so: cannot open shared object file: No such file or directory)
# ALSA lib pcm_direct.c:1997:(snd1_pcm_direct_parse_open_conf) The field ipc_gid must be a valid group (create group audio)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_pulse.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_pulse.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_pulse.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_pulse.so: cannot open shared object file: No such file or directory)
# ALSA lib pcm_direct.c:1997:(snd1_pcm_direct_parse_open_conf) The field ipc_gid must be a valid group (create group audio)
# ALSA lib pcm_direct.c:1997:(snd1_pcm_direct_parse_open_conf) The field ipc_gid must be a valid group (create group audio)
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.hdmi.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM hdmi
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.hdmi.0:CARD=0,AES0=4,AES1=130,AES2=0,AES3=2'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM hdmi
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.modem.0:CARD=0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline:CARD=0,DEV=0
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.modem.0:CARD=0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.phoneline:CARD=0,DEV=0
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.modem.0:CARD=0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM phoneline
# ALSA lib confmisc.c:1369:(snd_func_refer) Unable to find definition 'cards.0.pcm.modem.0:CARD=0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM phoneline
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_oss.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_oss.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_oss.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_oss.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_pulse.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_pulse.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_pulse.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_pulse.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_upmix.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_upmix.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_upmix.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_upmix.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_vdownmix.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_vdownmix.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_vdownmix.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_vdownmix.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_usb_stream.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_usb_stream.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_usb_stream.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_usb_stream.so: cannot open shared object file: No such file or directory)
# ALSA lib pcm_direct.c:1997:(snd1_pcm_direct_parse_open_conf) The field ipc_gid must be a valid group (create group audio)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_pulse.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_pulse.so: cannot open shared object file: No such file or directory)
# ALSA lib dlmisc.c:337:(snd_dlobj_cache_get0) Cannot open shared library libasound_module_pcm_pulse.so (/run/media/aadimprajapati/New Volume/fnclick/python/nlp/voice-to-text/env/lib/alsa-lib/libasound_module_pcm_pulse.so: cannot open shared object file: No such file or directory)
# 🎤 Speak something...

# %%
with open("speech.wav", "wb") as f:
    f.write(audio.get_wav_data())

# %%
result = model.transcribe("speech.wav")
print("📝 Transcription:", result["text"])
# Out:
# 📝 Transcription:  a little one frame
